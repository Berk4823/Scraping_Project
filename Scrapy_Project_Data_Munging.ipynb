# %%
###########################################
###########################################
############## Data Munging ###############
###########################################
###########################################


import re 
import pandas as pd 
import numpy as np 
from collections import Counter
# loading packages/aliasing

# %%
Reviews = pd.read_csv("Charlie.csv", encoding = "latin1")
# Read in the dataframe, normal coding does not work so I used "latin1"

# %%
Reviews.Score = Reviews.Score.map(str)
# Despite wanting Score in integer form, temporarily converting to string in order to 
# apply strip to the entire Data Frame
Reviews = Reviews.apply(lambda x: x.str.strip())
# Stripping white-space types from the data frame

# %%
# There are a few shows that I am not using, so I am going to remove those now.
set(Reviews["Show_Name"])
Reviews = Reviews.loc[(Reviews["Show_Name"] != "Indecent") & (Reviews["Show_Name"] != "Marvin's Room") \
               & (Reviews["Show_Name"] != "1984 (Broadway)")]

# %%
Reviews = Reviews[["Show_Name", "Review_Date", "Score", "Level", "Title", "User", "Name_Crit"]]
# Selecting only the columns I want

# %%
Reviews.Level = Reviews.Level.str.findall("positive|mixed|negative")
# Extract out only "positive", "negative", and "mixed" from the string. 
Reviews.Level = pd.Series([i[0] for i in Reviews.Level])
# convert back to a series of strings

# %%
Reviews = Reviews.loc[~Reviews.Title.isnull()]
# removing the rows without a Title review. (approx 19)

# %%
Reviews.columns = ["Show_Name", "Review_Date", "Score", "Review_Strength", "Description", "Reviewer", "Critic_Name"]
# Changing some of the Column Names to be a bit more descriptive. 
Reviews.columns
# Out:
# Index(['Show_Name', 'Review_Date', 'Score', 'Review_Strength', 'Description',
#        'Reviewer', 'Critic_Name'],
#       dtype='object')

# %%
np.sum(Reviews.isnull(), axis=0)
# There are a ton of missings in Critic_Name but I am not really using this column- It is only 
# there to give some reference for the review. 

# As for review_strength, I was able to determine the criteria from the site for positive, negative, and mixed. 
# I will create these values for the missing ones in the next cell. 

Reviews.Score = Reviews.Score.map(int)

# %%
y = []
for i in Reviews["Score"]:
    if i >= 70:
        y.append("positive")
    if i <= 69 and i >= 50:
        y.append("mixed")
    if i <= 49:
        y.append("negative")
# the above loop is creating a Review_Strength value based upon the proper score. Below I proceed to drop the old 
# column and add in y as the new column. I know this is not the best way to do this but I continued to get errors 
# when attempting to reassign the values using slices so I decided to do it like this instead. 

Reviews.drop("Review_Strength", axis=1)
# drop the old column 
Reviews.reset_index(drop = True)
# reset the index in order to properly add in the new column
Reviews["Review_Strength"] = y
# make the edited Review_Strength

# %%
pd.options.mode.chained_assignment = None
# supposed to allow me to slice like in R
Reviews.Description.loc[Reviews.Description == ","] = "No Comment"
# changed the Critic Reviews from "," to "No Comment" for clarity

# %%
np.sum(Reviews.isnull(), axis=0)
# Out:
# Show_Name              0
# Review_Date            0
# Score                  0
# Review_Strength        0
# Description            0
# Reviewer               9
# Critic_Name        90906
# dtype: int64

# %%
Reviews.head()
# Out:
#   Show_Name       Review_Date  Score Review_Strength Description  \
# 0  Hamilton  August 6th, 2015    100        positive  No Comment
# 1  Hamilton  August 6th, 2015    100        positive  No Comment
# 2  Hamilton  August 6th, 2015     80        positive  No Comment
# 3  Hamilton  August 7th, 2015     90        positive  No Comment
# 4  Hamilton  August 6th, 2015    100        positive  No Comment
#
#                 Reviewer         Critic_Name
# 0           Ben Brantley  The New York Times
# 1        Zachary Stewart        Theatermania
# 2  Elisabeth Vincentelli       New York Post
# 3           Michael Dale       BroadwayWorld
# 4         Marilyn Stasio             Variety

# %%
BPrice = pd.read_csv("BPrice_Final.csv")

# %%
BPrice.head()
# Out:
#   Show_Name Show_Duration                Theater  Capacity Performance_Date  \
# 0   Aladdin  2hrs, 30mins  New Amsterdam Theatre      1801       2017-08-01
# 1   Aladdin  2hrs, 30mins  New Amsterdam Theatre      1801       2017-08-02
# 2   Aladdin  2hrs, 30mins  New Amsterdam Theatre      1801       2017-08-02
# 3   Aladdin  2hrs, 30mins  New Amsterdam Theatre      1801       2017-08-03
# 4   Aladdin  2hrs, 30mins  New Amsterdam Theatre      1801       2017-08-04
#
#    Performance_Month  Performance_Day Performance_Time  Minimum_Price  \
# 0                  8                3         19:00:00           57.5
# 1                  8                4         13:00:00           57.5
# 2                  8                4         19:00:00           57.5
# 3                  8                5         19:00:00           57.5
# 4                  8                6         20:00:00           57.5
#
#    Maximum_Price
# 0          227.5
# 1          215.5
# 2          215.5
# 3          215.5
# 4          215.5

# %%
# I will join on Show_Name, but I want to make sure all the show names are identical. 

print(set(Reviews.Show_Name))
set(BPrice.Show_Name)

# Show_Names that need to change: A Bronx Tale: The Musical, On Your Feet, Charlie and the Chocolate Factory, 
# School of Rock - The Musical, Beautiful- The Carol King Musical, Natasha, Pierre & the Great Comet of 1812, 
# A Doll's House Part 2,
# Out:
# {'Hamilton', 'Groundhog Day The Musical', 'Wicked', 'The Book of Mormon', 'Kinky Boots', 'On Your Feet!', 'Cats', 'Anastasia', 'Charlie and The Chocolate Factory', 'War Paint', 'The Play That Goes Wrong', 'School of Rock - The Musical', 'Hello, Dolly!', 'Beautiful: The Carole King Musical', 'Aladdin', 'The Phantom of the Opera', 'Come From Away', 'A Bronx Tale', 'Natasha, Pierre & The Great Comet of 1812', 'The Lion King', 'Bandstand', 'Waitress', 'Miss Saigon', 'Chicago', "A Doll's House, Part 2", 'Dear Evan Hansen'}
# {'A Bronx Tale: The Musical',
#  "A Doll's House: Part 2",
#  'Aladdin',
#  'Anastasia',
#  'Bandstand',
#  'Beautiful - The Carole King Musical',
#  'Cats',
#  'Charlie and the Chocolate Factory',
#  'Chicago',
#  'Come From Away',
#  'Dear Evan Hansen',
#  'Groundhog Day',
#  'Hamilton',
#  'Hello, Dolly!',
#  'Kinky Boots',
#  'Miss Saigon',
#  'Natasha, Pierre, and the Great Comet of 1812',
#  'On Your Feet',
#  'School of Rock',
#  'The Book of Mormon',
#  'The Lion King',
#  'The Phantom of the Opera',
#  'The Play That Goes Wrong',
#  'Waitress',
#  'War Paint',
#  'Wicked'}

# %%
Reviews.Show_Name[Reviews.Show_Name == "Groundhog Day The Musical"] = "Groundhog Day"
Reviews.Show_Name[Reviews.Show_Name == "Charlie and The Chocolate Factory"] = "Charlie and the Chocolate Factory"
Reviews.Show_Name[Reviews.Show_Name == "School of Rock - The Musical"] = "School of Rock"
Reviews.Show_Name[Reviews.Show_Name == "On Your Feet!"] = "On Your Feet"
Reviews.Show_Name[Reviews.Show_Name == "Beautiful: The Carole King Musical"] = "Beautiful - The Carole King Musical"
Reviews.Show_Name[Reviews.Show_Name == "A Bronx Tale"] = "A Bronx Tale: The Musical"
Reviews.Show_Name[Reviews.Show_Name == "Natasha, Pierre & The Great Comet of 1812"] = "Natasha, Pierre, and the Great Comet of 1812"
Reviews.Show_Name[Reviews.Show_Name == "A Doll's House, Part 2"] = "A Doll's House: Part 2"
# Adjusting all the names from Reviews to be identical to the names from BPrice
# Before I join though, I want to fix up the descriptions column, I want to keep it as is but I want to be able to 
# extract information from it.

# %%
# I want to count the common descriptions among the movies. Without using NLP I can still have a good analysis here 
# because with my site, the Descriptions of the vast majority of users were preselected Adjectives- meaning spelling and 
# word lemmatization will not be as big of an issue here. I am going to group by show, and then find the 10 most common
# descriptions for each Show_Name. (Not Counting "No Comment" because these are just empty values). Then I will join
# this with the original table. 
Top10_Descriptions = Reviews.groupby(["Show_Name"]).agg({"Description": lambda x: Counter([j[0] for j in \
                                [str(i).split(",") for i in x] if j[0] != "No Comment"]).most_common(20)})
# This really long piece of code only looks complicated because there are a lot of steps in the lambda function. 
# It is grouping by Show_Name and aggregating like so- split the descriptions observations into separate strings
# and then for each show count the most common 10 shows, but not if the description is "No Comment" I did this all
# in one step because I am very bad with Python syntax for slicing on multi-level data frames :( -- Not worth
# wasting time for something I can do in one step. It is pretty clear what it is doing by looking at the table below. 
Top10_Descriptions
# Out:
#                                                                                     Description
# Show_Name
# A Bronx Tale: The Musical                     [(Funny, 170), (Absorbing, 110), (Great acting...
# A Doll's House: Part 2                        [(Funny, 272), (Absorbing, 172), (Clever, 110)...
# Aladdin                                       [(Funny, 1844), (Delightful, 759), (Enchanting...
# Anastasia                                     [(Delightful, 189), (Enchanting, 131), (Absorb...
# Bandstand                                     [(Absorbing, 116), (Delightful, 104), (Ambitio...
# Beautiful - The Carole King Musical           [(Delightful, 1192), (Absorbing, 827), (Funny,...
# Cats                                          [(Clever, 490), (Delightful, 413), (Absorbing,...
# Charlie and the Chocolate Factory             [(Funny, 216), (Clever, 66), (Disappointing, 4...
# Chicago                                       [(Funny, 1120), (Clever, 451), (Absorbing, 410...
# Come From Away                                [(Absorbing, 474), (Funny, 229), (Clever, 138)...
# Dear Evan Hansen                              [(Absorbing, 840), (Great acting, 322), (Funny...
# Groundhog Day                                 [(Funny, 611), (Clever, 242), (Ambitious, 87),...
# Hamilton                                      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# Hello, Dolly!                                 [(Funny, 414), (Delightful, 266), (Absorbing, ...
# Kinky Boots                                   [(Funny, 2739), (Delightful, 653), (Clever, 55...
# Miss Saigon                                   [(Absorbing, 379), (Epic, 136), (Ambitious, 11...
# Natasha, Pierre, and the Great Comet of 1812  [(Ambitious, 639), (Absorbing, 527), (Clever, ...
# On Your Feet                                  [(Delightful, 98), (Funny, 52), (Entertaining,...
# School of Rock                                [(Funny, 1322), (Delightful, 284), (Clever, 15...
# The Book of Mormon                            [(Funny, 3199), (Clever, 968), (Original, 571)...
# The Lion King                                 [(Absorbing, 1919), (Delightful, 1506), (Cleve...
# The Phantom of the Opera                      [(Absorbing, 2795), (Enchanting, 1765), (Delig...
# The Play That Goes Wrong                      [(Funny, 436), (Clever, 116), (Ambitious, 30),...
# Waitress                                      [(Funny, 1225), (Delightful, 486), (Absorbing,...
# War Paint                                     [(Great acting, 161), (Funny, 131), (Ambitious...
# Wicked                                        [(Absorbing, 3595), (Funny, 3471), (Clever, 28...

# %%
Top10_Descriptions.Description["The Lion King"]
# Just checking here to make sure I can slice properly for the invidivual shows- I will probably 
# be doing this in the graphing section, so I want to be able to reference this syntax.
# Out:
# [('Absorbing', 1919),
#  ('Delightful', 1506),
#  ('Clever', 1093),
#  ('Enchanting', 1072),
#  ('Ambitious', 948),
#  ('Original', 766),
#  ('Funny', 753),
#  ('Epic', 258),
#  ('Exquisite', 134),
#  ('Great acting', 133),
#  ('Masterful', 107),
#  ('Must see', 92),
#  ('Entertaining', 71),
#  ('Disappointing', 67),
#  ('Beautiful', 38),
#  ('Overrated', 33),
#  ('Intense', 32),
#  ('Dizzying', 27),
#  ('Banal', 19),
#  ('Edgy', 14)]

# %%
Reviews = pd.merge(Reviews, Top10_Descriptions, left_on = "Show_Name", right_index = True)
# I have merged into Reviews the Top 10 descriptions for each show now. The last thing that I want to do before I 
# begin graphing is add in price data. For the most part I want to keep the two data frames separate , but I will 
# want to merge the Minimum Price from BPrice into Reviews for when I compare the Price with
# the score. 
Reviews
# Out:
#                                Show_Name          Review_Date  Score  \
# 0                               Hamilton     August 6th, 2015    100
# 1                               Hamilton     August 6th, 2015    100
# 2                               Hamilton     August 6th, 2015     80
# 3                               Hamilton     August 7th, 2015     90
# 4                               Hamilton     August 6th, 2015    100
# 5                               Hamilton     August 6th, 2015    100
# 6                               Hamilton     August 6th, 2015     95
# 7                               Hamilton     August 6th, 2015     95
# 8                               Hamilton     August 6th, 2015     95
# 9                               Hamilton     August 6th, 2015     95
# 10                              Hamilton     August 6th, 2015     95
# 11                              Hamilton     August 6th, 2015     60
# 12                              Hamilton     August 7th, 2015    100
# 13                              Hamilton     August 6th, 2015    100
# 14                              Hamilton     August 6th, 2015     95
# 15                              Hamilton     August 6th, 2015     95
# 16                              Hamilton     August 6th, 2015     95
# 17                              Hamilton      April 1st, 2016     95
# 18                              Hamilton     August 6th, 2015    100
# 19                              Hamilton   February 9th, 2016    100
# 20                              Hamilton    August 21st, 2015     98
# 21                              Hamilton     August 6th, 2015     90
# 22                              Hamilton   October 13th, 2016     93
# 23                              Hamilton     August 7th, 2015    100
# 24                              Hamilton  November 17th, 2015     95
# 25                              Hamilton      June 12th, 2017     95
# 26                              Hamilton       June 9th, 2017     93
# 27                              Hamilton       June 8th, 2017     95
# 28                              Hamilton       May 26th, 2017    100
# 29                              Hamilton       May 20th, 2017     99
# ...                                  ...                  ...    ...
# 50095  Charlie and the Chocolate Factory     April 22nd, 2017     91
# 50096  Charlie and the Chocolate Factory     April 22nd, 2017     71
# 50097  Charlie and the Chocolate Factory     April 21st, 2017     80
# 50098  Charlie and the Chocolate Factory     April 20th, 2017    100
# 50099  Charlie and the Chocolate Factory     April 20th, 2017     86
# 50112         Kaitlyn P 7095                          NaN
# 50113              Alex 7091                          NaN
# 50114            Lucy S 7088                          NaN
# 50115             Humberto C                          NaN
# 50116           Stephen 7107                          NaN
# 50117           Melanie 7107                          NaN
# 50118            Jackie 7100                          NaN
# 50119                   BenC                          NaN
# 50395         Allison F 6210                          NaN
# 50396              Todd 7099                          NaN
# 50397           Spencer 7099                          NaN
# 50398                 Alix E                          NaN
# 50399             Barbara 10                          NaN
#
#                                            Description_y
# 0      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 1      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 2      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 3      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 4      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 5      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 6      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 7      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 8      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 9      [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 10     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 11     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 12     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 13     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 14     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 15     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 16     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 17     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 18     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 19     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 20     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 21     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 22     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 23     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 24     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 25     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 26     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 27     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 28     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# 29     [(Absorbing, 2459), (Original, 1238), (Ambitio...
# ...                                                  ...
# 50095  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50096  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50097  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50098  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50099  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50100  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50101  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50102  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50103  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50104  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50105  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50106  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50107  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50108  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50109  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50110  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50111  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50112  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50113  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50114  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50115  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50116  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50117  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50118  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50119  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50395  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50396  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50397  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50398  [(Funny, 216), (Clever, 66), (Disappointing, 4...
# 50399  [(Funny, 216), (Clever, 66), (Disappointing, 4...
#
# [92165 rows x 8 columns]

# %%
# What I actually want to merge though is one value for each show- the "minimum" Minimum_price. So I will 
# group_by and agg to get this, and then pd.merge into Reviews. 

BPrice_onlyprice = BPrice.groupby(["Show_Name"]).agg({"Minimum_Price": "min"})
Reviews = pd.merge(Reviews, BPrice_onlyprice, left_on = "Show_Name", right_index = True)
Reviews.head()
# Out:
#   Show_Name       Review_Date  Score Review_Strength Description_x  \
# 0  Hamilton  August 6th, 2015    100        positive    No Comment
# 1  Hamilton  August 6th, 2015    100        positive    No Comment
# 2  Hamilton  August 6th, 2015     80        positive    No Comment
# 3  Hamilton  August 7th, 2015     90        positive    No Comment
# 4  Hamilton  August 6th, 2015    100        positive    No Comment
#
#                 Reviewer         Critic_Name  \
# 0           Ben Brantley  The New York Times
# 1        Zachary Stewart        Theatermania
# 2  Elisabeth Vincentelli       New York Post
# 3           Michael Dale       BroadwayWorld
# 4         Marilyn Stasio             Variety
#
#                                        Description_y  Minimum_Price
# 0  [(Absorbing, 2459), (Original, 1238), (Ambitio...          749.0
# 1  [(Absorbing, 2459), (Original, 1238), (Ambitio...          749.0
# 2  [(Absorbing, 2459), (Original, 1238), (Ambitio...          749.0
# 3  [(Absorbing, 2459), (Original, 1238), (Ambitio...          749.0
# 4  [(Absorbing, 2459), (Original, 1238), (Ambitio...          749.0

# %%
# Now I just want to Rename the new columns
Reviews.columns = ["Show_Name", "Review_Date", "Score", "Review_Strength", "Description", "Reviewer", \
                  "Critic_Name", "Top10_Adjectives", "Lowest_Price"]
Reviews.columns
# Out:
# Index(['Show_Name', 'Review_Date', 'Score', 'Review_Strength', 'Description',
#        'Reviewer', 'Critic_Name', 'Top10_Adjectives', 'Lowest_Price'],
#       dtype='object')

# %%
Reviews.to_csv("Reviews_Final.csv", index = False)
# Now I will export this to to a csv so that when I begin data visualization I will load in the cleaned data.
